# %% [markdown]
# # Number of Clusters
#
# This experiment has the purpose of defining the number of clusters presented in the data. For that, we use the t-SNE for the projection of the data (dimensionality reduction), and an error metric to determine the best number of clusters. The metrics used are: square of the 2-norm distance metric, silhouette score and Davies-Bouldin Index.
#
# In this notebook we employed the **Silhouette score**. This metriccomputes how similar a sample is to its own cluster compared to other clusters. Its interval is [-1,1], where higher values indicate an appropriate configuration of the clusters.
#
# Metrics such as adjusted rand index, mutual information based scores, homogeneity, completeness and V-measure can not be used in this work because they require the ground truth (true labels) of the data.

# %%
import sys
sys.path.append('../')
from src import reader as r
from src import visualization as v

# %%
import numpy as np
import sklearn
import sklearn
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.metrics import silhouette_score

# %%
X = r.readWord2Vec()
print(X[:10])
print(X.shape)
# Out:
# ['word2vec.csv', 'bags.csv', 'health.txt', 'health-dataset.zip', 'health-dataset']
# [[ 0.02987077 -0.15110606 -0.02884087 ...,  0.02446168 -0.08834651
#   -0.09221231]
#  [ 0.05298314 -0.05420527  0.02592565 ...,  0.01782615 -0.02950471
#    0.00508323]
#  [ 0.07016749 -0.05757345 -0.13483836 ...,  0.10909334 -0.0250241
#   -0.0654501 ]
#  ...,
#  [ 0.10532002 -0.05241808 -0.02433    ..., -0.01405231  0.03333547
#    0.01318201]
#  [ 0.10429937 -0.1797766  -0.05073992 ...,  0.01325834 -0.18105656
#   -0.07903843]
#  [ 0.13153867 -0.05729359 -0.04480435 ..., -0.00396843 -0.05132721
#    0.00955163]]
# (13229, 128)

# %%
from MulticoreTSNE import MulticoreTSNE as TSNE

smp_sz = 7000
tsne_bow = TSNE(n_jobs=-1,n_components=2, perplexity=500, verbose=True)
tsne_bow_result = tsne_bow.fit_transform(X[:smp_sz])

# %% [markdown]
# ## Silhouette Method --- K-means
# This methods aims to define the best number of clusters (K) by the silhouette score.

# %%
silhouette = 0
Ks = []
Ss = []
Epsilon = 0.1
it = 1
J = 0.

k = 2
print("###############################")
while (silhouette < Epsilon):
    print("Number of Clusters:",k)
    print("Starting K-means++")
    cluster = KMeans(n_jobs=-1,n_clusters=k,random_state=42)
    cluster_result = cluster.fit(X)
    print("Finished")    
    silhouette = silhouette_score(X,cluster_result.labels_)
    Ss.append(silhouette)
    print("avg silhouette of", silhouette)    
    Ks.append(k)
    k += 100
    it += 1
    print("###############################")
    
best_K = k-100
print("\nBest k:",best_K)
print("Number of iterations:",it)
# Out:
# ###############################
# Number of Clusters: 2
# Starting K-means++
# Finished
# avg silhouette of 0.0374535850286
# ###############################
# Number of Clusters: 102
# Starting K-means++
# Finished
# avg silhouette of 0.00739169150097
# ###############################
# Number of Clusters: 202
# Starting K-means++
# Finished
# avg silhouette of 0.0144750868184
# ###############################
# Number of Clusters: 302
# Starting K-means++
# Finished
# avg silhouette of 0.0190881748247
# ###############################
# Number of Clusters: 402
# Starting K-means++
# Finished
# avg silhouette of 0.0243346191202
# ###############################
# Number of Clusters: 502
# Starting K-means++
# Finished
# avg silhouette of 0.0268698014845
# ###############################
# Number of Clusters: 602
# Starting K-means++
# Finished
# avg silhouette of 0.0281363018242
# ###############################
# Number of Clusters: 702
# Starting K-means++
# Finished
# avg silhouette of 0.0306771940394
# ###############################
# Number of Clusters: 802
# Starting K-means++
# Finished
# avg silhouette of 0.0339367197536
# ###############################
# Number of Clusters: 902
# Starting K-means++
# Finished
# avg silhouette of 0.0397078458872
# ###############################
# Number of Clusters: 1002
# Starting K-means++
# Finished
# avg silhouette of 0.0406188780217
# ###############################
# Number of Clusters: 1102
# Starting K-means++
# Finished
# avg silhouette of 0.0443060049851
# ###############################
# Number of Clusters: 1202
# Starting K-means++
# Finished
# avg silhouette of 0.0476046252427
# ###############################
# Number of Clusters: 1302
# Starting K-means++
# Finished
# avg silhouette of 0.0525104630746
# ###############################
# Number of Clusters: 1402
# Starting K-means++
# Finished
# avg silhouette of 0.0541785239745
# ###############################
# Number of Clusters: 1502
# Starting K-means++
# Finished
# avg silhouette of 0.0541552711642
# ###############################
# Number of Clusters: 1602
# Starting K-means++
# Finished
# avg silhouette of 0.0588245397228
# ###############################
# Number of Clusters: 1702
# Starting K-means++
# Finished
# avg silhouette of 0.0612130444208
# ###############################
# Number of Clusters: 1802
# Starting K-means++
# Finished
# avg silhouette of 0.0639641665642
# ###############################
# Number of Clusters: 1902
# Starting K-means++
# Finished
# avg silhouette of 0.0634406521676
# ###############################
# Number of Clusters: 2002
# Starting K-means++
# Finished
# avg silhouette of 0.067330806923
# ###############################
# Number of Clusters: 2102
# Starting K-means++
# Finished
# avg silhouette of 0.0683754756907
# ###############################
# Number of Clusters: 2202
# Starting K-means++
# Finished
# avg silhouette of 0.0721871638814
# ###############################
# Number of Clusters: 2302
# Starting K-means++
# Finished
# avg silhouette of 0.0722996576615
# ###############################
# Number of Clusters: 2402
# Starting K-means++
# Finished
# avg silhouette of 0.0736772767839
# ###############################
# Number of Clusters: 2502
# Starting K-means++
# Finished
# avg silhouette of 0.0761220392205
# ###############################
# Number of Clusters: 2602
# Starting K-means++
# Finished
# avg silhouette of 0.0770838767783
# ###############################
# Number of Clusters: 2702
# Starting K-means++
# Finished
# avg silhouette of 0.080230068281
# ###############################
# Number of Clusters: 2802
# Starting K-means++
# Finished
# avg silhouette of 0.078543346327
# ###############################
# Number of Clusters: 2902
# Starting K-means++
# Finished
# avg silhouette of 0.08375698444
# ###############################
# Number of Clusters: 3002
# Starting K-means++
# Finished
# avg silhouette of 0.0839592980294
# ###############################
# Number of Clusters: 3102
# Starting K-means++
# Finished
# avg silhouette of 0.0847841748602
# ###############################
# Number of Clusters: 3202
# Starting K-means++
# Finished
# avg silhouette of 0.0858039217975
# ###############################
# Number of Clusters: 3302
# Starting K-means++
# Finished
# avg silhouette of 0.0875204841463
# ###############################
# Number of Clusters: 3402
# Starting K-means++
# Finished
# avg silhouette of 0.0872890339037
# ###############################
# Number of Clusters: 3502
# Starting K-means++
# Finished
# avg silhouette of 0.090495481418
# ###############################
# Number of Clusters: 3602
# Starting K-means++
# Finished
# avg silhouette of 0.0907548454284
# ###############################
# Number of Clusters: 3702
# Starting K-means++
# Finished
# avg silhouette of 0.0920902428146
# ###############################
# Number of Clusters: 3802
# Starting K-means++
# Finished
# avg silhouette of 0.0935767753994
# ###############################
# Number of Clusters: 3902
# Starting K-means++
# Finished
# avg silhouette of 0.0934735264019
# ###############################
# Number of Clusters: 4002
# Starting K-means++
# Finished
# avg silhouette of 0.0946699988956
# ###############################
# Number of Clusters: 4102
# Starting K-means++
# Finished
# avg silhouette of 0.0972004858396
# ###############################
# Number of Clusters: 4202
# Starting K-means++
# Finished
# avg silhouette of 0.0990024931774
# ###############################
# Number of Clusters: 4302
# Starting K-means++
# Finished
# avg silhouette of 0.0979566514429
# ###############################
# Number of Clusters: 4402
# Starting K-means++
# Finished
# avg silhouette of 0.0997538436809
# ###############################
# Number of Clusters: 4502
# Starting K-means++
# Finished
# avg silhouette of 0.100820221518
# ###############################
#
# Best k: 4502
# Number of iterations: 47

# %%
print("#############################")
print("Best K =", best_K)
print("Applying K-means")
best_cluster = KMeans(n_clusters=best_K)
best_cluster_result = best_cluster.fit(X)
print("Finished")
print("#############################")
# Out:
# #############################
# Best K = 4502
# Applying K-means
# Finished
# #############################

# %%
true_label = best_cluster_result.labels_

# %%
v.visualize_sup_scatter(tsne_bow_result, true_label[:smp_sz])
# Out:
# <module 'matplotlib.pyplot' from '/opt/conda/lib/python3.6/site-packages/matplotlib/pyplot.py'>
