# %% [markdown]
# # Non Normed
#
# This experiment has the purpose of defining the number of clusters presented in the data. For that, we use the t-SNE for the projection of the data (dimensionality reduction), and an error metric to determine the best number of clusters. The metrics used are: square of the 2-norm distance metric, silhouette score and Davies-Bouldin Index.
#
# Metrics such as adjusted rand index, mutual information based scores, homogeneity, completeness and V-measure can not be used in this work because they require the ground truth (true labels) of the data.

# %%
import sys
sys.path.append('../')
from src import optimizer as _optimizer
from src import reader as _reader
from src import visualization as _visualization
import numpy as np
import sklearn
from sklearn.cluster import KMeans
# Out:
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
X = _reader.readWord2Vec(normed=False)
print(X[:10])
print(X.shape)
# Out:
# ['word2vec.csv', 'bags.csv', 'health.txt', 'health-dataset.zip', 'health-dataset']
# [[ 0.02987077 -0.15110606 -0.02884087 ...  0.02446168 -0.08834651
#   -0.09221231]
#  [ 0.05298314 -0.05420527  0.02592565 ...  0.01782615 -0.02950471
#    0.00508323]
#  [ 0.07016749 -0.05757345 -0.13483836 ...  0.10909334 -0.0250241
#   -0.0654501 ]
#  ...
#  [ 0.10532002 -0.05241808 -0.02433    ... -0.01405231  0.03333547
#    0.01318201]
#  [ 0.10429937 -0.1797766  -0.05073992 ...  0.01325834 -0.18105656
#   -0.07903843]
#  [ 0.13153867 -0.05729359 -0.04480435 ... -0.00396843 -0.05132721
#    0.00955163]]
# (13229, 128)

# %%
best_K, Ks, Js = _optimizer.elbow_kmeans(X)
# Out:
# ###############################
# Number of Clusters: 2
# Starting K-means++
# Finished
# J = 0.44881818336885326
# error = 0.44881818336885326
# ###############################
# Number of Clusters: 12
# Starting K-means++
# Finished
# J = 0.4127350519494086
# error = 0.036083131419444636
# ###############################
# Number of Clusters: 22
# Starting K-means++
# Finished
# J = 0.39894356075238313
# error = 0.013791491197025496
# ###############################
# Number of Clusters: 32
# Starting K-means++
# Finished
# J = 0.3910374274913084
# error = 0.007906133261074755
# ###############################
#
# Best k: 32
# Number of iterations: 5

# %%
_visualization.plot_cluster_errors(Ks,Js)
# Out:
# J  [0.44881818336885326, 0.4127350519494086, 0.39894356075238313, 0.3910374274913084]
# Ks  [2, 12, 22, 32]
# <module 'matplotlib.pyplot' from '/opt/conda/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## Refining the Search
# The error threshould was reach with 32 clusters, then we can refine our search while increasing the steps from 10 to 1.

# %%
best_K, Ks, Js = _optimizer.elbow_kmeans(X, min_k=32, step=1)
# Out:
# ###############################
# Number of Clusters: 32
# Starting K-means++
# Finished
# J = 0.3910374274913084
# error = 0.3910374274913084
# ###############################
# Number of Clusters: 33
# Starting K-means++
# Finished
# J = 0.38964085171150553
# error = 0.0013965757798028444
# ###############################
#
# Best k: 33
# Number of iterations: 3

# %%
_visualization.plot_cluster_errors(Ks,Js)
# Out:
# J  [0.3910374274913084, 0.38964085171150553]
# Ks  [32, 33]
# <module 'matplotlib.pyplot' from '/opt/conda/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# For KMeans there was only a marginal Gain while increasing the clusters passing by this point.
# To make sure we made a bigger step otmizations to see where it will stop.

# %%
best_K, Ks, Js = _optimizer.elbow_kmeans(X, min_k=2, step=100)
# Out:
# ###############################
# Number of Clusters: 2
# Starting K-means++
# Finished
# J = 0.44881818336885326
# error = 0.44881818336885326
# ###############################
# Number of Clusters: 102
# Starting K-means++
# Finished
# J = 0.3619095672103342
# error = 0.08690861615851908
# ###############################
# Number of Clusters: 202
# Starting K-means++
# Finished
# J = 0.3437326025929062
# error = 0.01817696461742796
# ###############################
# Number of Clusters: 302
# Starting K-means++
# Finished
# J = 0.33152804796683816
# error = 0.012204554626068065
# ###############################
# Number of Clusters: 402
# Starting K-means++
# Finished
# J = 0.3222750485213225
# error = 0.009252999445515664
# ###############################
#
# Best k: 402
# Number of iterations: 6

# %%
_visualization.plot_cluster_errors(Ks,Js)
# Out:
# J  [0.44881818336885326, 0.3619095672103342, 0.3437326025929062, 0.33152804796683816, 0.3222750485213225]
# Ks  [2, 102, 202, 302, 402]
# <module 'matplotlib.pyplot' from '/opt/conda/lib/python3.6/site-packages/matplotlib/pyplot.py'>
